# %%
import extract_training_data

# %%
! python extract_training_data_2.py data/dev.conll data/input_dev.npy data/target_dev.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...................................................
# Writing output...

# %%
! python extract_training_data_2.py data/train.conll data/input_train.npy data/target_train.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...............................................................................................................................................................................................................................................................................................................................................................................................................
# Writing output...

# %%
! python extract_training_data_3.py data/dev.conll data/input_dev.npy data/target_dev.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...................................................
# Writing output...

# %%
! python extract_training_data.py data/dev.conll data/input_dev.npy data/target_dev.npy
# Out:
# Starting feature extraction... (each . represents 100 sentences)
# ...................................................
# Writing output...

# %%
! python train_model.py data/input_train.npy data/target_train.npy data/model.h5
# Out:
# Compiling model.
# 2022-04-06 22:49:54.314845: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Done loading data.
# Epoch 1/5
# 18996/18996 [==============================] - 120s 6ms/step - loss: 0.4946
# Epoch 2/5
# 18996/18996 [==============================] - 119s 6ms/step - loss: 0.4143
# Epoch 3/5
# 18996/18996 [==============================] - 115s 6ms/step - loss: 0.3993
# Epoch 4/5
# 18996/18996 [==============================] - 116s 6ms/step - loss: 0.3909
# Epoch 5/5
# 18996/18996 [==============================] - 118s 6ms/step - loss: 0.3869

# %%
! python decoder_2.py data/model.h5 data/dev.conll
# Out:
# Streaming output truncated to the last 5000 lines.
# 7	sponsor	_	_	NN	_	6	conj	_	_
# 8	of	_	_	IN	_	7	conj	_	_
# 9	President	_	_	NNP	_	10	poss	_	_
# 10	Bush	_	_	NNP	_	12	nn	_	_
# 11	's	_	_	POS	_	12	nn	_	_
# 12	clean-air	_	_	JJ	_	8	conj	_	_
# 13	bill	_	_	NN	_	12	advmod	_	_
# 14	,	_	_	,	_	13	conj	_	_
# 15	plans	_	_	VBZ	_	14	conj	_	_
# 16	to	_	_	TO	_	15	conj	_	_
# 17	unveil	_	_	VB	_	16	conj	_	_
# 18	a	_	_	DT	_	17	conj	_	_
# 19	surprise	_	_	NN	_	18	conj	_	_
# 20	proposal	_	_	NN	_	19	conj	_	_
# 21	that	_	_	WDT	_	20	conj	_	_
# 22	would	_	_	MD	_	21	conj	_	_
# 23	break	_	_	VB	_	22	conj	_	_
# 24	with	_	_	IN	_	23	conj	_	_
# 25	the	_	_	DT	_	24	conj	_	_
# 26	White	_	_	NNP	_	27	poss	_	_
# 27	House	_	_	NNP	_	29	nn	_	_
# 28	on	_	_	IN	_	29	nn	_	_
# 29	a	_	_	DT	_	25	conj	_	_
# 30	centerpiece	_	_	NN	_	29	advmod	_	_
# 31	issue	_	_	NN	_	30	conj	_	_
# 32	:	_	_	:	_	31	conj	_	_
# 33	acid	_	_	JJ	_	32	conj	_	_
# 34	rain	_	_	NN	_	33	conj	_	_
# 35	.	_	_	.	_	34	conj	_	_
#
# 1	The	_	_	DT	_	0	root	_	_
# ...

# %%
! python decoder.py data/model.h5 data/dev.conll
# Out:
# 2022-04-07 01:19:44.114173: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 1	``	_	_	``	_	0	root	_	_
# 2	Feeding	_	_	NNP	_	3	poss	_	_
# 3	Frenzy	_	_	NNP	_	1	conj	_	_
# 4	''	_	_	''	_	5	nn	_	_
# 5	-LRB-	_	_	-LRB-	_	3	conj	_	_
# 6	Henry	_	_	NNP	_	7	nn	_	_
# 7	Holt	_	_	NNP	_	10	nn	_	_
# 8	,	_	_	,	_	10	nn	_	_
# 9	326	_	_	CD	_	10	number	_	_
# 10	pages	_	_	NNS	_	5	advmod	_	_
# 11	,	_	_	,	_	10	advmod	_	_
# 12	$	_	_	$	_	11	conj	_	_
# 13	19.95	_	_	CD	_	14	nsubj	_	_
# 14	-RRB-	_	_	-RRB-	_	12	conj	_	_
# 15	,	_	_	,	_	14	conj	_	_
# 16	a	_	_	DT	_	15	conj	_	_
# 17	highly	_	_	RB	_	16	conj	_	_
# 18	detailed	_	_	VBN	_	17	conj	_	_
# 19	account	_	_	NN	_	18	conj	_	_
# 20	of	_	_	IN	_	19	conj	_	_
# 21	the	_	_	DT	_	20	conj	_	_
# 22	Wedtech	_	_	NNP	_	24	nn	_	_
# 23	scandal	_	_	NN	_	24	nn	_	_
# 24	,	_	_	,	_	21	conj	_	_
# 25	begins	_	_	VBZ	_	24	advmod	_	_
# 26	on	_	_	IN	_	25	conj	_	_
# 27	a	_	_	DT	_	26	conj	_	_
# ...

# %%
! python evaluate.py data/model.h5 data/dev.conll
# Out:
# 2022-04-07 01:20:11.517145: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Evaluating. (Each . represents 100 test dependency trees)
# .........
